# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tool import BridgeProject

# %%
# Out:
# ****CROSS SECTION PROPERTIES****
# Centroid (x̄, ȳ) from bottom: (74.0360 mm, 52.6244 mm)
# Moment of inertia I (mm^4) about horizontal centroidal axis: 854359.7642
# Q above centroid (mm^3): 9790.6923
# Q below centroid (mm^3): 9790.6923
#
# ***** SFD/BMD ENVELOPE SUMMARY *****
# Max shear (abs): 257.3333, positions: [(856, 0), (1200, 1200)]
# Max moment (abs): 69445.3333, positions: [(984, 644), (1072, 556)]
